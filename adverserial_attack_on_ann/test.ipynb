# %% [markdown]
# # Unzipping the model, and the noised spectogram images

# %%
# !unzip my_model.zip
# !unzip noised_spec.zip
# Out:
# Archive:  my_model.zip
#    creating: my_model/assets/
#  extracting: my_model/fingerprint.pb
#   inflating: my_model/keras_metadata.pb
#   inflating: my_model/saved_model.pb
#    creating: my_model/variables/
#   inflating: my_model/variables/variables.data-00000-of-00001
#   inflating: my_model/variables/variables.index
# Archive:  noised_spec.zip
#    creating: noised_spec/
#    creating: noised_spec/up/
#   inflating: noised_spec/up/34.png
#   inflating: noised_spec/up/72.png
#   inflating: noised_spec/up/17.png
#   inflating: noised_spec/up/128.png
#   inflating: noised_spec/up/191.png
#   inflating: noised_spec/up/5.png
#   inflating: noised_spec/up/116.png
#   inflating: noised_spec/up/144.png
#   inflating: noised_spec/up/45.png
#   inflating: noised_spec/up/32.png
#   inflating: noised_spec/up/134.png
#   inflating: noised_spec/up/15.png
#   inflating: noised_spec/up/108.png
#   inflating: noised_spec/up/92.png
#   inflating: noised_spec/up/54.png
# ...

# %%
import tensorflow as tf
from tensorflow import keras

# %%
IMAGE_SHAPE = (369, 496)
VALID_DATA_DIR = '/content/noised_spec/' # replace with your generated test set in here

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

valid_generator = datagen.flow_from_directory(
    VALID_DATA_DIR,
    shuffle=False,
    target_size=IMAGE_SHAPE,
)
# Out:
# Found 1599 images belonging to 8 classes.

# %%
model = keras.models.load_model('my_model')

# %% [markdown]
# # Model's original accuracy

# %%
model.evaluate(valid_generator)
# Out:
# 50/50 [==============================] - 14s 273ms/step - loss: 0.9821 - accuracy: 0.6906
# [0.9821140766143799, 0.690625011920929]

# %% [markdown]
# # On my noised spectograms

# %%
model.evaluate(valid_generator)
# Out:
# 50/50 [==============================] - 93s 2s/step - loss: 2.3175 - accuracy: 0.3734
# [2.3174664974212646, 0.3733583390712738]
